# %%
import pandas as pd

# %%
df = pd.read_csv(r"..\LBG Reboot 2025 LDN - Health Demo Data\1_liwei_control_health_conscious_young_adult.csv")
df
# Out:
#             Date      Time  Heart Rate (bpm)  Heart Rate Variability (ms)  \
# 0     1-Mar-2025  00:00:00                66                           61
# 1     1-Mar-2025  01:00:00                56                           68
# 2     1-Mar-2025  02:00:00                61                           74
# 3     1-Mar-2025  03:00:00                59                           45
# 4     1-Mar-2025  04:00:00                59                           82
# ..           ...       ...               ...                          ...
# 715  30-Mar-2025  19:00:00                63                           51
# 716  30-Mar-2025  20:00:00                62                           69
# 717  30-Mar-2025  21:00:00                59                           72
# 718  30-Mar-2025  22:00:00                58                           87
# 719  30-Mar-2025  23:00:00                62                           57
#
#      Respiratory Rate (breaths/min)  Blood Oxygen (%)  Step Count (steps)  \
# ...

# %%
df["Datetime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Heart Rate (bpm)', 'Heart Rate Variability (ms)',
#        'Respiratory Rate (breaths/min)', 'Blood Oxygen (%)',
#        'Step Count (steps)', 'Walking Speed (km/h)',
#        'Distance Walked/Run (km)', 'Flights Climbed (flights)',
#        'Active Energy Burned (kcal)', 'Stand Hours (hours)',
#        'Sleep Duration (hours)', 'Time Awake (minutes)', 'REM Sleep (%)',
#        'Core Sleep (%)', 'Deep Sleep (%)', 'Environmental Sound Level (dB)',
#        'Headphone Audio Exposure (dB)', 'VO2 Max (mL/kg/min)',
#        'ECG (ST Segment Elevation) (mm)', 'Body Temperature (°C)',
#        'Exercise Minutes (minutes)', 'Elevation Gain (meters)',
#        'Running Pace (min/km)', 'Mindfulness Minutes (minutes)', 'Datetime'],
#       dtype='object')
